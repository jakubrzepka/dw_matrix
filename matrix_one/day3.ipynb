# %%
from google.colab import drive
import pandas as pd 
import numpy as np

# %%
# !pip install datadotworld
# Out:
# Collecting datadotworld
#   Downloading https://files.pythonhosted.org/packages/eb/2d/564c9b9056c414528f7a91c48bc33f2243bd5323ac07d52269002bd3d6c6/datadotworld-1.7.0-py2.py3-none-any.whl (158kB)
#      |████████████████████████████████| 163kB 4.9MB/s
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2.6.1)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2019.11.28)
# Collecting datapackage<2.0a,>=1.6.2
#   Downloading https://files.pythonhosted.org/packages/b8/75/0a2e0853116d2fe3f6422f7844129eba9939e54c530706d6116545438401/datapackage-1.11.1-py2.py3-none-any.whl (84kB)
#      |████████████████████████████████| 92kB 11.9MB/s
# Collecting configparser<4.0a,>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/ab/1a/ec151e5e703ac80041eaccef923611bbcec2b667c20383655a06962732e9/configparser-3.8.1-py2.py3-none-any.whl
# Collecting tableschema<2.0a,>=1.5.2
#   Downloading https://files.pythonhosted.org/packages/3c/a5/75ebdbf57b828edd1c7b059d3ff86b1c23d7bd69daae4c16199c124f4aa3/tableschema-1.12.5-py2.py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 9.1MB/s
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2.21.0)
# Collecting tabulator>=1.22.0
#   Downloading https://files.pythonhosted.org/packages/56/5c/e57ce30b0751c9071f848e9eb3bda128a921fff13ea442fc1059206cceb2/tabulator-1.34.0-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 10.0MB/s
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (1.24.3)
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (1.12.0)
# Collecting click<7.0a,>=6.0
#   Downloading https://files.pythonhosted.org/packages/34/c1/8806f99713ddb993c5366c362b2f908f18269f8d792aff1abfd700775a77/click-6.7-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (2.6.0)
# Collecting unicodecsv>=0.14
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Collecting cchardet>=1.0
#   Downloading https://files.pythonhosted.org/packages/fa/4e/847feebfc3e71c773b23ee06c74687b8c50a5a6d6aaff452a0a4f4eb9a32/cchardet-2.1.5-cp36-cp36m-manylinux1_x86_64.whl (241kB)
#      |████████████████████████████████| 245kB 53.4MB/s
# Collecting jsonpointer>=1.10
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Collecting isodate>=0.5.4
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Collecting rfc3986>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/00/8d/9d56bfe43997f1864fe0891be69bc239ded98e69c9f56eb9eaa5b1789660/rfc3986-1.3.2-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld) (3.0.4)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.3.13)
# Collecting linear-tsv>=1.0
#   Downloading https://files.pythonhosted.org/packages/82/e5/03207a0f11e1d60df85b97b61704ed701b725a7c2feaf83f7bfbd0c2d83e/linear-tsv-1.1.0.tar.gz
# Collecting ijson>=2.5
#   Downloading https://files.pythonhosted.org/packages/23/42/2066f77a714ab7221542ea23710b35a96c5dd398f1933429088afd888293/ijson-2.6.1-cp36-cp36m-manylinux1_x86_64.whl (65kB)
#      |████████████████████████████████| 71kB 9.8MB/s
# Requirement already satisfied: boto3>=1.9 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.11.10)
# Collecting jsonlines>=1.1
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.1.0)
# Collecting openpyxl>=2.6
#   Downloading https://files.pythonhosted.org/packages/95/8c/83563c60489954e5b80f9e2596b93a68e1ac4e4a730deb1aae632066d704/openpyxl-3.0.3.tar.gz (172kB)
#      |████████████████████████████████| 174kB 50.2MB/s
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.10 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (1.14.10)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.3.2)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.4.1)
# Requirement already satisfied: et_xmlfile in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.0.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.10->boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.15.2)
# Building wheels for collected packages: unicodecsv, linear-tsv, openpyxl
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10768 sha256=9bd74f0c350465ca1dab93c6367def1a189684a57453dc03e46e2b2da84081a1
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
#   Building wheel for linear-tsv (setup.py) ... done
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-cp36-none-any.whl size=7383 sha256=588aef16e342a5e638443afcf5b459c3d0cc1de6a14084393bd12692b05b5609
#   Stored in directory: /root/.cache/pip/wheels/3f/8a/cb/38917fd1ef4356b9870ace7331b83417dc594bf2c029bd991f
#   Building wheel for openpyxl (setup.py) ... done
#   Created wheel for openpyxl: filename=openpyxl-3.0.3-py2.py3-none-any.whl size=241262 sha256=c8e4511de23fac72151dbd3f0bde4bc35a3152515bfc4f97b9a34bde86bb8706
#   Stored in directory: /root/.cache/pip/wheels/b5/85/ca/e768ac132e57e75e645a151f8badac71cc0089e7225dddf76b
# Successfully built unicodecsv linear-tsv openpyxl
# Installing collected packages: click, linear-tsv, unicodecsv, cchardet, ijson, jsonlines, openpyxl, tabulator, isodate, rfc3986, tableschema, jsonpointer, datapackage, configparser, datadotworld
#   Found existing installation: Click 7.0
#     Uninstalling Click-7.0:
#       Successfully uninstalled Click-7.0
#   Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# Successfully installed cchardet-2.1.5 click-6.7 configparser-3.8.1 datadotworld-1.7.0 datapackage-1.11.1 ijson-2.6.1 isodate-0.6.0 jsonlines-1.2.0 jsonpointer-2.0 linear-tsv-1.1.0 openpyxl-3.0.3 rfc3986-1.3.2 tableschema-1.12.5 tabulator-1.34.0 unicodecsv-0.14.1

# %%
# !pip install datadotworld[pandas]
# Out:
# Requirement already satisfied: datadotworld[pandas] in /usr/local/lib/python3.6/dist-packages (1.7.0)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2019.11.28)
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2.6.1)
# Requirement already satisfied: datapackage<2.0a,>=1.6.2 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.11.1)
# Requirement already satisfied: click<7.0a,>=6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (6.7)
# Requirement already satisfied: configparser<4.0a,>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (3.8.1)
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2.21.0)
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.12.0)
# Requirement already satisfied: tabulator>=1.22.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.34.0)
# Requirement already satisfied: tableschema<2.0a,>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.12.5)
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.24.3)
# Collecting numpy<=1.16.4; extra == "pandas"
#   Downloading https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 233kB/s
# Collecting pandas<0.25; extra == "pandas"
#   Downloading https://files.pythonhosted.org/packages/19/74/e50234bc82c553fecdbd566d8650801e3fe2d6d8c8d940638e3d8a7c5522/pandas-0.24.2-cp36-cp36m-manylinux1_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 42.7MB/s
# Requirement already satisfied: cchardet>=1.0 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.1.5)
# Requirement already satisfied: unicodecsv>=0.14 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.0)
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld[pandas]) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld[pandas]) (3.0.4)
# Requirement already satisfied: jsonlines>=1.1 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.2.0)
# Requirement already satisfied: linear-tsv>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.0.3)
# Requirement already satisfied: ijson>=2.5 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (2.6.1)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: boto3>=1.9 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.11.10)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.3.13)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.6/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (0.6.0)
# Requirement already satisfied: rfc3986>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (1.3.2)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas<0.25; extra == "pandas"->datadotworld[pandas]) (2018.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld[pandas]) (1.0.1)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld[pandas]) (1.4.1)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.3.2)
# Requirement already satisfied: botocore<1.15.0,>=1.14.10 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (1.14.10)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.9.4)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.10->boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.15.2)
# ERROR: plotnine 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: mizani 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=0.25.0; python_version >= "3.0", but you'll have pandas 0.24.2 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, pandas
#   Found existing installation: numpy 1.17.5
#     Uninstalling numpy-1.17.5:
#       Successfully uninstalled numpy-1.17.5
#   Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
# Successfully installed numpy-1.16.4 pandas-0.24.2

# %%
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50Ompha3VicnplcCIsImlzcyI6ImFnZW50Ompha3VicnplcDo6NDQxMWZiOGEtOTg3ZS00NzEyLTkxNDktM2Y4MzgyOTJiMmZkIiwiaWF0IjoxNTgxNTk3MzMyLCJyb2xlIjpbInVzZXJfYXBpX3JlYWQiLCJ1c2VyX2FwaV93cml0ZSJdLCJnZW5lcmFsLXB1cnBvc2UiOnRydWUsInNhbWwiOnt9fQ.bnlPK-7bQimgjdaqTQ7Mi8s-QFypUk1VpVTZI1batLLm7F_d8GPaL8VnZHd6fQeqYAjMivHdhLgW01o007XDog

# %%
import datadotworld as dw

# %%
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ef5b1e3843da> in <module>()
# ----> 1 drive.mount("/content/drive")
#
# NameError: name 'drive' is not defined

# %%
cd /content/
ls
# Out:
#   File "<ipython-input-4-76b26931e34c>", line 1
#     cd /content/
#                 ^
# SyntaxError: invalid syntax

# %%
# !cd /content

# %%
# !ls
# Out:
# sample_data

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
cd ..
# Out:
# /content

# %%
mkdir drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
ls
# Out:
#   File "<ipython-input-18-0b573ca2d3f9>", line 1
#     cd drive/
#            ^
# SyntaxError: invalid syntax

# %%
cd ./drive/
# Out:
# /content/drive

# %%
cd "My Drive/Colab Notebooks"
# Out:
#   File "<ipython-input-21-8d7689df7d71>", line 1
#     cd "My Drive/Colab Notebooks"
#                                 ^
# SyntaxError: invalid syntax

# %%
cd "/content/drive/My\ Drive/Colab Notebooks"
# Out:
# [Errno 2] No such file or directory: '/content/drive/My\\ Drive/Colab Notebooks'
# /content/drive

# %%
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3e30156ce8ad> in <module>()
# ----> 1 pwd
#       2
#
# NameError: name 'pwd' is not defined

# %%
# !pwd
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
cd 'My Drive'
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# '02-09-2019 - Grupa Traderow.pdf'
# '#2 backtesty.gsheet'
# '3L Pawła na Sierra.gdoc'
#  4n6/
# '5.2019 - notatki.gdoc'
# 'ABCs Of VSA.zip'
#  aktywny.html
#  akwizycja/
# 'Analiza pogody.gdoc'
#  Android/
#  Arkusze/
# 'Arkusz kalkulacyjny bez nazwy.gsheet'
# 'Arkusz kalkulacyjny bez tytułu (1).gsheet'
# 'Arkusz kalkulacyjny bez tytułu.gsheet'
# 'Backtest 3L na D1.gsheet'
# 'Back test S#1 na wyższych TFach.gsheet'
# 'Backtesty KTSD.gsheet'
# 'Backtesty MMD.gsheet'
# 'Backtesty Oddalenie.gsheet'
# 'Backtesty reakcji ceny na TS z H1 .gsheet'
# 'Backtesty - STD (1).gsheet'
# 'Backtesty - STD.gsheet'
# 'Backtesty - zmiana Kumo.gsheet'
#  backup-csv/
# 'backup-csv (1)'/
# ' baza 1.gdoc'
# 'Będlewo 2019.gslides'
#  Biegły/
# 'Budget 1.gsheet'
#  Budget.gsheet
#  Budowa/
#  Budzet/
# 'Chaos trading.gdoc'
#  Checklisty.gdoc
#  Classroom/
# 'Colab Notebooks'/
# 'Crude scenariusz TS z H1 .gsheet'
# 'CYBERBEZPIECZEŃSTWO w administracji.gslides'
# 'Cykle Ichimoku.gsheet'
#  DanceTOC.gdoc
#  dane.gdoc
# 'Dane giełdowe'/
# 'Dear Andrea,.gdoc'
# 'DiNapoli (1).gdoc'
#  DiNapoli.gdoc
# 'Disciplined Trader Trade Journal (Lots).xlsx'
# 'Dokument bez nazwy.gdoc'
# 'Dokument bez tytułu.gdoc'
#  Dziennik.gdoc
# '!Dziennik.gsheet'
#  Edu/
#  Exam.gdoc
# 'Firmy na budowę.gdoc'
#  Forex/
#  Fuelio/
# 'Fuelio (1)'/
#  Giełda/
#  GOLD-2009.csv
#  GOLD-2010.csv
#  GOLD-2011.csv
#  GOLD-2012.csv
# 'GOLD-2013 (1).csv'
#  GOLD-2013.csv
#  GOLD-2014.csv
#  GOLD-2015.csv
#  GOLD-2016.csv
#  GOLD-2017.csv
#  GOLD-2018.csv
#  GRO/
# 'Habit Tracker.gsheet'
# 'Hosda i Sasaki ksiazki'/
# 'HOUSEHOLD BUDGET TEMPLATE.gsheet'
# 'How to Save Facebook Video Without Software.pdf'
# 'Ichimoku tłumaczenia z Włoskich stron.gdoc'
#  indicators/
#  Inter-Lers.gdoc
# 'Jacek 2019-11-18 19-30.mp4'
#  Jacek_2020-01-05_streszczenie_podejścia_do_rynku.mp4
# 'Jacek strategia M1 2019-10-27 20-30.mp4'
#  jedzenie/
# 'Kody źródłowe '/
# 'Kopia Backtesty reakcji ceny na TS z H1.gsheet'
# 'Kopia REAGOWANIE NA INCYDENTY BEZPIECZEŃSTWA IT – PRZYKŁADOWA DOKUMENTACJA.gdoc'
#  KR.odt
# 'KTSD opis.gdoc'
#  Kwity/
# 'Lets Dinapoli Day 4.gdoc'
# 'Linki - szkolenie.gdoc'
#  Linux/
#  magisterka/
# 'Master Swing Newsletter'/
# 'MasterSwingNewsletter Feb-20(1) .gdoc'
# 'MasterSwingNewsletter Feb-20(1) .pdf'
# 'Modelowanie SL z ATR.gdoc'
# 'Mózg się lasuje.gdoc'
#  NCFI/
# 'NCFI campus notes.gdoc'
# 'NCFI Core Case Report.gdoc'
# 'NCFI Core exam 11.12.2019 Jakub Rzepka.gdoc'
# 'NCFI Core exam Jakub Rzepka.gdoc'
# 'NIEAKTUALNE Backtest schemat z CHS.gsheet'
# 'Notatki Ichi.gdoc'
# 'Notatki Sierra.gdoc'
# 'Nowy budżet.gsheet'
# 'Odbicie od KS.gdoc'
# 'Oferta usług doradczych.gslides'
#  OHLC/
#  OIL-2009.csv
#  OIL-2010.csv
#  OIL-2011.csv
#  OIL-2012.csv
#  OIL-2013.csv
#  OIL-2014.csv
#  OIL-2015.csv
#  OIL-2016.csv
#  OIL-2017.csv
# 'OIL-2018 (1).csv'
#  OIL-2018.csv
#  OIL-2019-NIEPELNY.CSV
#  Opinie.gdoc
# 'Oznaczenia schematów.gdoc'
#  Papiery/
#  Paulinka/
# 'PBMW '/
#  Pictures/
# 'Pictures (1)'/
# 'Pictures (2)'/
# 'Pictures (3)'/
# 'Pictures (4)'/
# 'Pictures (5)'/
# 'Pictures (6)'/
#  Ping_Pong_Trade.gslides
#  Ping_Pong_Trade.pptx
# 'pismo_przeowdnie-czes 3.pdf'
#  praca_magisterska/
# 'Praca naukowa – prosta (1).gdoc'
# 'Praca naukowa – prosta.gdoc'
# 'prezentacja___6 adr2.gslides'
# 'Prezentacja bez tytułu (1).gslides'
# 'Prezentacja bez tytułu (2).gslides'
# 'Prezentacja bez tytułu.gslides'
#  prezentacja.gslides
#  Prezentacje/
# 'Raport .gdoc'
# 'RE Linki.gdoc'
# 'Rossmann Repair Training Guide.gslides'
#  routes/
# 'routes (1)'/
# 'routes (2)'/
# 'routes (3)'/
# 'Runy spekulacyjne.gdoc'
#  rzepka_jakub.gdoc
# 'Schemat #2.gdoc'
#  Sec/
#  SierraChart/
# 'skan postanowienia.pdf'
#  Skrypty/
# 'SL z ATR.gdoc'
#  Stasiu/
# 'Statystyki DOW  lata miesięcznie.gsheet'
# '!Statystyki DOW  miesiące rok do roku 2009-2018.gsheet'
# 'Statystyki DOW porownanie dni roczne 1999-2018.gsheet'
# 'Statystyki DOW porownanie dni roczne 2009-2018.gsheet'
# 'Statystyki Gold.gsheet'
# 'Statystyki GOLD miesiące rok do roku 2009-2018.gsheet'
# 'Statystyki GOLD porównanie dni roczne 2009-2018.gsheet'
# 'Statystyki OIL porównanie dni roczne 2009-2018.gsheet'
# 'Statystyki -roczne porównanie dni handlu.gsheet'
# 'Statystyki Soya.gsheet'
# 'Statystyki SP500 porownanie dni roczne.gsheet'
# '!Statystyki WTI  miesiące rok do roku 2009-2018.gsheet'
#  Studia/
#  Sygnały.gdoc
# 'Symbole CQG.gsheet'
#  symbols.xlsx
# 'Symulacja przychodu.gsheet'
#  sync/
# 'sync (1)'/
# 'sync (2)'/
# 'sync (3)'/
# 'SZABLON Statystyki miesiące rok do roku 2009-2018.gsheet'
# 'Szkolenie sieci.gslides'
#  tata/
# 'Testowo o raporcie COT.gdoc'
#  Titanic.gdoc
# 'Trade Journal.gsheet'
# 'Trade Journal.xls'
#  Trening/
#  VSATradeguiderBooks.zip
#  WAZNA_KOPIA_GENERATOR/
# 'webinarium 21.01.2019.gdoc'
# 'WKS pierwszy test.gsheet'
# 'WKS test2.gsheet'
#  www/
# 'Wymiary okien.gsheet'
# 'Wymiary otworów okiennych.gdoc'
#  Wywiad/
# 'Wzory pism'/
#  X/
#  Xmind/
#  XTIUSD-D1.csv
#  Z340_ZM.gsheet
# 'Zabezpieczenia .gslides'
#  Zbieranka/
# 'złote myśli Wojtek.gdoc'
# 'Życiorys .gdoc'

# %%
cd 'Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
cd dw_matrix
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# %ls
# Out:
# HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
df = dw.dataframes['7004_1']
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()

# %%
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins                brand  ...  vin websiteids  weight
# 11128  AVpfZg-01cnluZ0-kFSS   NaN               Pakems  ...  NaN        NaN     NaN
# 19297  AVpf0kxj1cnluZ0-r6MR   NaN  AH by Android Homme  ...  NaN        NaN     NaN
# 17312  AVpf96Lx1cnluZ0-uRIn   NaN                  DDI  ...  NaN        NaN     NaN
# 5279   AVpfIYfbLJeJML433Cvk   NaN               adidas  ...  NaN        NaN     NaN
# 333    AVpfD6x9ilAPnD_xUFUl   NaN    Polo Ralph Lauren  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df_usd = df[df.prices_currency == 'USD'].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile(df_usd['prices_amountmin'],99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
df.to_csv('data/shoes_prices.csv',index=False)
